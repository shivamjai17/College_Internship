# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url='https://www.flipkart.com/poco-m3-power-black-64-gb/p/itmb49cc10841be2?pid=MOBFZTCUTAYPJHHR&lid=LSTMOBFZTCUTAYPJHHR2ZVC1N&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=352ae6e3-6e28-4a0d-8e70-05c323008336.MOBFZTCUTAYPJHHR.SEARCH&ppt=None&ppn=None&ssid=s0zhfhpxg00000001627835331878&qH=532c28d5412dd75b'

# %%
a='mobiles'
url1='https://www.flipkart.com/search?q={}&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=on&as=off&as-pos=2&as-type=HISTORY'.format(a)

# %%
resp=requests.get(url1)

# %%
soup=BeautifulSoup(resp.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
name=[]
ratting=[]
mrp=[]
nrat=[]
acprice=[]
off=[]

# %%
name
# Out:
# []

# %%
print(nrat)
# Out:
# []

# %%
c=0
for i in soup.find_all('div',attrs={"class":"_3pLy-c row"}):
    nam=i.find('div',attrs={'class':"_4rR01T"})
    name.append(nam.text)
    rat=i.find('div',attrs={'class':"gUuXy-"})
    rating.append(rat.text)
    rt=i.find('span',attrs={'class':'_1lRcqv'})
    nrat.append(rt.text)
    price=i.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    mrp.append(price.text)
    ap=i.find('div',attrs={"class":'_3I9_wc _27UcVY'})
    acprice.append(ap.text)
    offer=i.find('div',attrs={'class':'_3Ay6Sb'})
    off.append(offer.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f79d774aed11> in <module>
#       4     name.append(nam.text)
#       5     rat=i.find('div',attrs={'class':"gUuXy-"})
# ----> 6     rating.append(rat.text)
#       7     rt=i.find('span',attrs={'class':'_1lRcqv'})
#       8     nrat.append(rt.text)
#
# NameError: name 'rating' is not defined

# %%
print(len(name))
print(len(ratting))
print(len(nrat))
print(len(mrp))
print(len(acprice))
print(len(off))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
ratting  gUuXy
# Out:
# []

# %%
name=[]
ratting=[]
mrp=[]
nrat=[]
price=[]
off=[]

# %%
##verticle,mobile
c=0
for page in range(1,11):
    u='https://www.flipkart.com/search?q=Tvs&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(page)
    res=requests.get(u)
    soup=BeautifulSoup(res.content,'html.parser')
    for i in soup.find_all('div',attrs={"class":"_3pLy-c row"}):
        nam=i.find('div',attrs={'class':"_4rR01T"})
        name.append(nam.text)
        if i.find('div',attrs={'class':"gUuXy-"}):
            rat=i.find('div',attrs={'class':"gUuXy-"})
            ratting.append(rat.text)
        else:
            ratting.append('0')
        if i.find('span',attrs={'class':'_1lRcqv'}):   
            rt=i.find('span',attrs={'class':'_1lRcqv'})
            nrat.append(rt.text)
        else:
            nrat.append('0')
        pric=i.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
        mrp.append(pric.text)
        if i.find('div',attrs={"class":'_3I9_wc _27UcVY'}):
            ap=i.find('div',attrs={"class":'_3I9_wc _27UcVY'})
            price.append(ap.text)
        else:
             price.append('0')
        if i.find('div',attrs={'class':'_3Ay6Sb'}):
            offer=i.find('div',attrs={'class':'_3Ay6Sb'})
            off.append(offer.text)
        else:
            off.append('0')
        c+=1    
    print('number of items :',c,'number of pages :',page )
# Out:
# number of items : 24 number of pages : 1
# number of items : 48 number of pages : 2
# number of items : 72 number of pages : 3
# number of items : 96 number of pages : 4
# number of items : 120 number of pages : 5
# number of items : 144 number of pages : 6
# number of items : 168 number of pages : 7
# number of items : 192 number of pages : 8
# number of items : 216 number of pages : 9
# number of items : 240 number of pages : 10
# number of items : 264 number of pages : 11
# number of items : 288 number of pages : 12
# number of items : 312 number of pages : 13
# number of items : 336 number of pages : 14

# %%
name=[]
brand=[]
mrp=[]
price=[]
off=[]

# %%
c=0
for page in range(1,10):
    u='https://www.flipkart.com/search?q=children dress&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(page)
    res=requests.get(u)
    soup=BeautifulSoup(res.content,'html.parser')
    for i in soup.find_all('div',attrs={'class':'_2B099V'}):
        if i.find('div',attrs={'class':'_2WkVRV'}):
            br=i.find('div',attrs={'class':'_2WkVRV'})
            brand.append(br.text)
        else:
            br=i.find('a',attrs={'class':"IRpwTa"})
            brand.append(br.text)
        tt=i.find('a',attrs={'class':"IRpwTa"})
        name.append(tt.text)
        pr=i.find('div',attrs={'class':'_30jeq3'})
        price.append(pr.text)
        if i.find('div',attrs={'class':'_3I9_wc'}):
            mr=i.find('div',attrs={'class':'_3I9_wc'})
            mrp.append(mr.text)
        else:
            mrp.append('0')
        if i.find('div',attrs={'class':'_3Ay6Sb'}):
            offer=i.find('div',attrs={'class':'_3Ay6Sb'})
            off.append(offer.text)
        else:
            off.append('0')
      
        c+=1
    print('items :',c,'pages :',page)
# Out:
# items : 40 pages : 1
# items : 80 pages : 2
# items : 120 pages : 3
# items : 160 pages : 4
# items : 200 pages : 5
# items : 240 pages : 6
# items : 280 pages : 7
# items : 320 pages : 8
# items : 360 pages : 9

# %%
starrat=[]
name=[]
price=[]
mrp=[]
off=[]
review=[]

# %%
c=0
d=10
for page in range(1,d):
    u='https://www.flipkart.com/search?q=books&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(page)
    res=requests.get(u)
    soup=BeautifulSoup(res.content,'html.parser')
    for i in soup.find_all('div',attrs={'class':'_4ddWXP'}):
        tt=i.find('a',attrs={'class':'s1Q9rs'})
        name.append(tt.text)
        if i.find('div',attrs={'class':'_3LWZlK'}):
            rat=i.find('div',attrs={'class':'_3LWZlK'})
            starrat.append(rat.text)
        else:
            starrat.append('0')
        if i.find('span',attrs={'class':'_2_R_DZ'}):
            rew=i.find('span',attrs={'class':'_2_R_DZ'})
            review.append(rew.text)
        else:
            review.append('0')
        pr=i.find('div',attrs={"class":"_30jeq3"})
        price.append(pr.text)
        if i.find('div',attrs={'_3I9_wc'}):
            mr=i.find('div',attrs={'_3I9_wc'})
            mrp.append(mr.text)
        else:
             mrp.append('0')
        if i.find('div',attrs={'class':'_3Ay6Sb'}):
            offer=i.find('div',attrs={'class':'_3Ay6Sb'})
            off.append(offer.text)
        else:
             off.append('0')
                               
                               
        c+=1
    print('items :',c,'pages :',page)
# Out:
# items : 40 pages : 1
# items : 80 pages : 2
# items : 120 pages : 3
# items : 160 pages : 4
# items : 200 pages : 5
# items : 240 pages : 6
# items : 280 pages : 7
# items : 320 pages : 8
# items : 360 pages : 9

# %%
title
# Out:
# ['Villain Eau de Parfum  -  20 ml',
#  'Enchanteur Beaute Eau de Cologne  -  100 ml',
#  'ENVY Combo Perfume For Men 60ML + 60ML Eau de Parfum  -...',
#  'ENVY Combo Perfume For Men and Women 60ML + 60ML Eau de...',
#  'FOGG Scent Impressio Eau de Parfum  -  100 ml',
#  'DENVER Hamilton Eau de Parfum  -  100 ml',
#  'ENVY Women Eau de Parfum  -  60 ml',
#  'Paris Elysees Dolce & Sense ROSE CENTIFOLIA Eau de Parf...',
#  'Wild Stone for Men, Ultra Sensual, 100ml Eau de Parfum ...',
#  'ENVY Men Perfume Eau de Parfum  -  30 ml',
#  'FOGG Scent I AM QUEEN Eau de Parfum  -  100 ml',
#  'USTRAA Cologne for Men- After Dark Perfume  -  100 ml',
#  'ENVY Women Perfume Eau de Parfum  -  30 ml',
#  'DENVER Hamilton Caliber Perfume 100 Ml Eau de Parfum  -...',
#  'FOGG Scent XPRESSIO Eau de Parfum  -  100 ml',
#  'Paris Elysees Dolce & Sense Jasmin Eau de Parfum  -  60...',
#  'FOGG Scent XTREMO Eau de Parfum  -  100 ml',
#  'FOGG Scent Make My Day Eau de Parfum  -  100 ml',
# ...

# %%
cate=input()
pages=int(input())
name=[]
ratting=[]
mrp=[]
nrat=[]
price=[]
off=[]
for page in range(pages):
    u='https://www.flipkart.com/search?q={}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(cate,page)
    res=requests.get(u)
    soup=BeautifulSoup(res.content,'html.parser')
    for i in soup.find_all('div',attrs={"class":"_3pLy-c row"}):
        nam=i.find('div',attrs={'class':"_4rR01T"})
        name.append(nam.text)
        if i.find('div',attrs={'class':"gUuXy-"}):
            rat=i.find('div',attrs={'class':"gUuXy-"})
            ratting.append(rat.text)
        else:
            ratting.append('0')
        if i.find('span',attrs={'class':'_1lRcqv'}):   
            rt=i.find('span',attrs={'class':'_1lRcqv'})
            nrat.append(rt.text)
        else:
            nrat.append('0')
            pric=i.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
            mrp.append(pric.text)
        if i.find('div',attrs={"class":'_3I9_wc _27UcVY'}):
            ap=i.find('div',attrs={"class":'_3I9_wc _27UcVY'})
            price.append(ap.text)
        else:
            price.append('0')
        if i.find('div',attrs={'class':'_3Ay6Sb'}):
            offer=i.find('div',attrs={'class':'_3Ay6Sb'})
            off.append(offer.text)
        else:
            off.append('0')
    if len(name)<1:
        print('wrong choice')
        break 
while len(price)>1:
    print('full')
    break
     
else:
    name=[]
    brand=[]
    mrp=[]
    price=[]
    off=[]
    for page in range(pages):
        u='https://www.flipkart.com/search?q={}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(cate,page)
        res=requests.get(u)
        soup=BeautifulSoup(res.content,'html.parser')
        for i in soup.find_all('div',attrs={'class':'_2B099V'}):
            if i.find('div',attrs={'class':'_2WkVRV'}):
                br=i.find('div',attrs={'class':'_2WkVRV'})
                brand.append(br.text)
            else:
                br=i.find('a',attrs={'class':"IRpwTa"})
                brand.append(br.text)
            tt=i.find('a',attrs={'class':"IRpwTa"})
            name.append(tt.text)
            pr=i.find('div',attrs={'class':'_30jeq3'})
            price.append(pr.text)
            if i.find('div',attrs={'class':'_3I9_wc'}):
                mr=i.find('div',attrs={'class':'_3I9_wc'})
                mrp.append(mr.text)
            else:
                mrp.append('0')
            if i.find('div',attrs={'class':'_3Ay6Sb'}):
                offer=i.find('div',attrs={'class':'_3Ay6Sb'})
                off.append(offer.text)
            else:
                off.append('0')
        if len(name)<1: 
            print('wrong2')
            break
while len(brand)>1:
    print('2full')
    break
else:
    starrat=[]
    name=[]
    price=[]
    mrp=[]
    off=[]
    review=[]
    for page in range(pages):
        u='https://www.flipkart.com/search?q={}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(cate,page)
        res=requests.get(u)
        soup=BeautifulSoup(res.content,'html.parser')
        for i in soup.find_all('div',attrs={'class':'_4ddWXP'}):
            tt=i.find('a',attrs={'class':'s1Q9rs'})
            name.append(tt.text)
            if i.find('div',attrs={'class':'_3LWZlK'}):
                rat=i.find('div',attrs={'class':'_3LWZlK'})
                starrat.append(rat.text)
            else:
                starrat.append('0')
            if i.find('span',attrs={'class':'_2_R_DZ'}):
                rew=i.find('span',attrs={'class':'_2_R_DZ'})
                review.append(rew.text)
            else:
                review.append('0')
            pr=i.find('div',attrs={"class":"_30jeq3"})
            price.append(pr.text)
            if i.find('div',attrs={'_3I9_wc'}):
                mr=i.find('div',attrs={'_3I9_wc'})
                mrp.append(mr.text)
            else:
                 mrp.append('0')
            if i.find('div',attrs={'class':'_3Ay6Sb'}):
                offer=i.find('div',attrs={'class':'_3Ay6Sb'})
                off.append(offer.text)
            else:
                 off.append('0')
# Out:
# perfume
# 2
# wrong choice
# wrong2

# %%
name
# Out:
# ['ENVY Combo Perfume For Men 60ML + 60ML Eau de Parfum  -...',
#  'ENVY Combo Perfume For Men and Women 60ML + 60ML Eau de...',
#  'FOGG Scent Impressio Eau de Parfum  -  100 ml',
#  'Enchanteur Beaute Eau de Cologne  -  100 ml',
#  'ENVY Women Eau de Parfum  -  60 ml',
#  'DENVER Hamilton Eau de Parfum  -  100 ml',
#  'ENVY Men Perfume Eau de Parfum  -  30 ml',
#  'All Good Scents Urbane Nights Sky, Perfume for Men Eau ...',
#  'Wild Stone for Men, Ultra Sensual, 100ml Eau de Parfum ...',
#  'FOGG Scent I AM QUEEN Eau de Parfum  -  100 ml',
#  'ENVY Women Perfume Eau de Parfum  -  30 ml',
#  'AXE Signature Gold Iced Vetiver & Fresh Lavender Eau de...',
#  'FOGG Scent XPRESSIO Eau de Parfum  -  100 ml',
#  'DENVER Hamilton Caliber Perfume 100 Ml Eau de Parfum  -...',
#  'FOGG Scent XTREMO Eau de Parfum  -  100 ml',
#  'AXE Signature Gold Black Musk & Cedar Wood Perfume Eau ...',
#  'FOGG Scent Intensio Eau de Parfum  -  100 ml',
#  'FOGG Scent Make My Day Eau de Parfum  -  100 ml',
# ...

# %%
rat=soup.find('span',attrs={'class':"_2_R_DZ"})

# %%
rat.text[:9]
# Out:
# '2,82,515 '

# %%
c=0
for i in soup.find_all('div',attrs={"class":"_30jeq3 _1_WHN1"}):
    print(i.text)
    c+=1
print(c)
# Out:
# ₹11,499
# ₹8,499
# ₹9,499
# ₹8,499
# ₹9,499
# ₹8,499
# ₹6,999
# ₹6,999
# ₹9,999
# ₹15,999
# ₹8,499
# ₹15,999
# ₹9,999
# ₹7,999
# ₹11,499
# ₹12,499
# ₹7,999
# ₹11,499
# ₹10,999
# ₹9,999
# ₹9,999
# ₹10,499
# ₹11,499
# ₹10,999
# 24

# %%
c=0
for i in soup.find_all('div',attrs={"class":"_3LWZlK"}):
    print(i.text)
    c+=1
print(c)
# Out:
# 4.3
# 4.4
# 4.4
# 4.4
# 4.4
# 4.3
# 4.4
# 4.4
# 4.4
# 4.4
# 4.3
# 4.4
# 4.4
# 4.5
# 4.3
# 4.4
# 4.3
# 4.3
# 4.3
# 4.3
# 4.4
# 4.4
# 4.3
# 4.3
# 4.4
# 5
# 4
# 4.3
# 5
# 3
# 4.4
# 4
# 5
# 4.4
# 5
# 5
# 4.4
# 4
# 1
# 39

# %%
c=0
for i in soup.find_all('div',attrs={"class":"_3Ay6Sb"}):
    print(i.text)
    c+=1
print(c)
# Out:
# 11% off
# 15% off
# 13% off
# 15% off
# 13% off
# 15% off
# 12% off
# 12% off
# 16% off
# 11% off
# 15% off
# 11% off
# 16% off
# 20% off
# 11% off
# 16% off
# 20% off
# 23% off
# 21% off
# 16% off
# 16% off
# 12% off
# 23% off
# 21% off
# 16% off
# 21% off
# 15% off
# 16% off
# 12% off
# 29

# %%
c=0
for i in soup.find_all('div',attrs={'class':'_3I9_wc _27UcVY'}):
    print(i.text)
    c+=1
print(c)
# Out:
# ₹12,999
# ₹9,999
# ₹10,999
# ₹9,999
# ₹10,999
# ₹9,999
# ₹7,999
# ₹7,999
# ₹11,999
# ₹17,999
# ₹9,999
# ₹17,999
# ₹11,999
# ₹9,999
# ₹12,999
# ₹14,999
# ₹9,999
# ₹14,999
# ₹13,999
# ₹11,999
# ₹11,999
# ₹11,999
# ₹14,999
# ₹13,999
# 24

# %%
mrp.text
# Out:
# '₹11,499'

# %%
try: 
    ratrew=soup.find('span',attrs={'class':"_2_R_DZ"})
     
except:
     ratrew=soup.find('div',attrs={'class':"_3tLJXl"})

# %%
ratrew.text
# Out:
# '564 ratings and 70 reviews'

# %%
ratting=soup.find('div',attrs={'class':"_3LWZlK"})

# %%
ratting.text
# Out:
# '3.7'

# %%
try:
    off=soup.find('div',attrs={'class':"_3Ay6Sb _31Dcoz"})
except:
    off=soup.find('div',attrs={'class':"_3Ay6Sb _31Dcoz pZkvcx"})

# %%
off.find('span')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-a9d63a324ca8> in <module>
# ----> 1 off.find('span')
#
# AttributeError: 'NoneType' object has no attribute 'find'
